# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr

# %%
para6 = xr.open_dataset(
    "/glade/work/addisus/scam_scripts/PPE_250_ensemble/parameter_34_100.nc"
)
para6 = para6.rename({"Sample_nmb": "ppe_ind"})
para6 = para6.set_coords("ppe_ind")


para6["ppe_ind"] = para6.ppe_ind.astype(int)
para6 = para6.to_dataframe().drop(columns = "ppe_ind")

# %%
para_nm = para6.columns

# %%
samples = np.random.rand(1000000, len(para_nm))
samples_pd = pd.DataFrame(samples, columns=para_nm)
#xr.Dataset.from_dataframe(samples_pd).to_netcdf("/glade/work/qingyuany/camml_v6/parameter_samples/" + "para_samples.nc")
