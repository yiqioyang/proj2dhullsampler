# %%
import xarray as xr
import pandas as pd
import glob
import os
import math

import numpy as np
import re
from joblib import Parallel, delayed
from pathlib import Path
import matplotlib.pyplot as plt
import alphashape
from itertools import combinations
from collections import defaultdict, deque
from concurrent.futures import ThreadPoolExecutor
from concurrent.futures import ProcessPoolExecutor, as_completed


from shapely import points, contains
import random

# %%
import seaborn as sns

# %%
from proj2dhullsampler import Analysis

# %%
working_dir = '/glade/work/qingyuany/camml_re/'
case_name = "v2"
#para = pd.read_csv("/glade/work/qingyuany/cam7_tuning/cam7/para/ppe0_original_scale.csv", index_col=0)
#para = pd.read_csv("/glade/work/qingyuany/camml_re/v2/post_simulations/", index_col=0)
#para = xr.open_dataset('/glade/work/addisus/scam_scripts/PPE_250_ensemble/parameter38_100.nc').to_dataframe()
#para = xr.open_dataset('/glade/work/qingyuany/camml_re/v0/parameter_34_100.nc').to_dataframe().drop(columns = 'Sample_nmb')


para = pd.read_csv("/glade/work/qingyuany/camml_re/v1/post_simulations/paras.csv", index_col=0)

nc = xr.open_dataset('/glade/work/qingyuany/camml_re/v1/post_simulations/batch_v1.nc').ppe_ind

# %%
# working_dir = '/glade/work/qingyuany/camml_re/'
# case_name = "v1"
# para = xr.open_dataset('/glade/work/qingyuany/camml_re/v0/parameter_34_100.nc').to_dataframe().drop(columns = 'Sample_nmb')
# para.index = para.index + 1


# nc = xr.open_dataset('/glade/work/qingyuany/camml_re/v0/initial_ppe.nc')

# %%
para = para.loc[nc.ppe_ind]
para.shape
# Out:
# (100, 34)

# %%
analysis = Analysis(working_dir, case_name, para)

# %%
analysis.plot_onehot(figsize = (8, 6))

# %%
_ = analysis.plot_by_para('clubb_c2rt', ncols=6, figsize = (20,20))

# %%
for c in list(analysis.meta_onehot.index[analysis.meta_onehot['clubb_c2rt']]):
    
    
    temp_out = analysis.p_emu[analysis.tf_masks[c]].clubb_c2rt.min()
    
    print(f'{c:20}: {temp_out:3.2f}')
# Out:
# LWCF_zonal_-25to-15 : 0.00
# LWCF_zonal_-15to-5  : 0.00
# LWCF_zonal_15to25   : 0.00
# TGCLDLWP_zonal_5to15: 0.00
# TMQ_zonal_-55to-45  : nan
# TMQ_zonal_-45to-35  : nan
# TMQ_zonal_-35to-25  : nan
# TMQ_zonal_-25to-15  : 0.50
# TMQ_zonal_-15to-5   : 0.05
# TMQ_zonal_-5to5     : 0.00
# TMQ_zonal_5to15     : 0.00
# TMQ_zonal_15to25    : 0.00
# TMQ_zonal_25to35    : 0.00
# TMQ_zonal_35to45    : 0.00
# TMQ_zonal_45to55    : 0.00
# FLUT_zonal_-25to-15 : 0.00
# FLUT_zonal_-15to-5  : 0.00
# FLUT_zonal_-5to5    : 0.00
# FLUT_zonal_5to15    : 0.00
# FLUT_zonal_15to25   : 0.00
# PRECT_zonal_-65to-55: 0.00
# PRECT_zonal_-35to-25: 0.00
# PRECT_zonal_-5to5   : 0.00
# PRECT_zonal_5to15   : nan

# %%
analysis.meta_onehot.index[analysis.meta_onehot['zmz']]
# Out:
# Index(['RESTOM_zonal_-75to-65', 'RESTOM_zonal_-25to-15',
#        'RESTOM_zonal_-15to-5', 'RESTOM_zonal_-5to5', 'RESTOM_zonal_5to15',
#        'RESTOM_zonal_15to25', 'RESTOM_zonal_25to35', 'FLNT_zonal_-75to-65',
#        'FLNT_zonal_-65to-55', 'FLNT_zonal_-55to-45', 'FLNT_zonal_-45to-35',
#        'FLNT_zonal_-35to-25', 'FLNT_zonal_-25to-15', 'FLNT_zonal_-15to-5',
#        'FLNT_zonal_-5to5', 'FLNT_zonal_5to15', 'FLNT_zonal_15to25',
#        'FLNT_zonal_25to35', 'FLNT_zonal_35to45', 'FLNT_zonal_45to55',
#        'FLNT_zonal_55to65', 'FLNT_zonal_65to75', 'LWCF_zonal_-75to-65',
#        'LWCF_zonal_-65to-55', 'LWCF_zonal_-55to-45', 'LWCF_zonal_-45to-35',
#        'LWCF_zonal_-35to-25', 'LWCF_zonal_-25to-15', 'LWCF_zonal_-15to-5',
#        'LWCF_zonal_-5to5', 'LWCF_zonal_5to15', 'LWCF_zonal_15to25',
#        'LWCF_zonal_25to35', 'LWCF_zonal_35to45', 'LWCF_zonal_45to55',
#        'LWCF_zonal_55to65', 'LWCF_zonal_65to75', 'PRECT_zonal_-65to-55',
#        'PRECT_zonal_-55to-45', 'PRECT_zonal_-45to-35', 'PRECT_zonal_-35to-25',
#        'PRECT_zonal_-25to-15', 'PRECT_zonal_-15to-5', 'PRECT_zonal_5to15',
#        'PRECT_zonal_25to35', 'PRECT_zonal_35to45', 'PRECT_zonal_45to55',
#        'PRECT_zonal_65to75', 'TMQ_zonal_-65to-55', 'TMQ_zonal_-55to-45',
#        'TMQ_zonal_-45to-35', 'TMQ_zonal_-35to-25', 'TMQ_zonal_-25to-15',
#        'TMQ_zonal_-15to-5', 'TMQ_zonal_-5to5', 'TMQ_zonal_5to15',
#        'TMQ_zonal_15to25', 'TMQ_zonal_25to35', 'TMQ_zonal_35to45',
#        'TMQ_zonal_45to55', 'TMQ_zonal_55to65', 'TMQ_zonal_65to75',
#        'LHFLX_zonal_-45to-35', 'LHFLX_zonal_-25to-15', 'LHFLX_zonal_-15to-5',
#        'LHFLX_zonal_-5to5', 'LHFLX_zonal_5to15', 'LHFLX_zonal_15to25',
#        'LHFLX_zonal_25to35', 'LHFLX_zonal_35to45', 'LHFLX_zonal_45to55'],
#       dtype='object')

# %%
xx = pd.concat([analysis.data.ppe_para_norm, analysis.data.pd_ppe['FLNT_zonal_25to35']], axis = 1)

# %%
_ = analysis.plot_by_para('zmconv_dmpdz', ncols=5, figsize = (15,10))

# %%
analysis.visualize_check('FSNTOA_zonal_-75to-65')

# %%
analysis.visualize_check('LWCF_zonal_-5to5')

# %%
analysis.visualize_check('precip095')

# %%
analysis.visualize_check('precip099')

# %%
analysis.data.ppe_para
# Out:
#      micro_mg_max_nicons  micro_mg_vtrmi_factor  micro_mg_iaccr_factor  \
# 1           1.000000e+08               1.200000               1.000000
# 2           1.000000e+08               1.000000               1.000000
# 3           1.000000e+08               1.366512               1.000000
# 4           4.272341e+09               0.961199               0.903760
# 5           2.412386e+09               1.154306               0.643733
# ..                   ...                    ...                    ...
# 96          5.504888e+09               1.379973               0.863044
# 97          6.872362e+09               1.180784               0.616506
# 98          3.000886e+09               1.185284               0.362943
# 99          5.094614e+09               0.830165               0.427537
# 100         1.399733e+09               1.218974               0.869642
#
#      micro_mg_berg_eff_factor  micro_mg_accre_enhan_fact  micro_mg_homog_size  \
# 1                    1.000000                   1.000000             0.000025
# 2                    1.000000                   1.000000             0.000025
# 3                    1.000000                   0.816432             0.000025
# 4                    0.922754                   1.535563             0.000072
# 5                    0.912887                   2.174603             0.000140
# ..                        ...                        ...                  ...
# 96                   0.994341                   1.633984             0.000114
# 97                   0.868917                   1.931125             0.000027
# 98                   0.997289                   1.156560             0.000066
# 99                   0.946186                   0.906342             0.000056
# 100                  0.959280                   1.711912             0.000052
#
#      micro_mg_dcs  clubb_c1  clubb_C8  clubb_c11  ...  sol_factb_interstitial  \
# 1        0.000500  1.000000  4.600000   0.700000  ...                0.100000
# 2        0.000500  1.000000  4.500000   0.700000  ...                0.100000
# 3        0.000503  1.000000  4.499788   0.700000  ...                0.100000
# 4        0.000510  1.584478  4.099929   0.472819  ...                0.486754
# 5        0.000540  1.019657  4.394596   0.663304  ...                0.709331
# ..            ...       ...       ...        ...  ...                     ...
# 96       0.000510  1.875885  4.933708   0.409387  ...                0.468806
# 97       0.000531  1.855914  4.355360   0.456915  ...                0.407661
# 98       0.000537  1.868289  4.512288   0.657381  ...                0.131440
# 99       0.000549  1.058901  4.677743   0.476598  ...                0.679545
# 100      0.000530  1.047720  4.394058   0.420531  ...                0.538928
#
#      sol_factic_interstitial  microp_aero_wsub_min  microp_aero_wsubi_min  \
# 1                   0.400000              0.100000               0.001000
# 2                   0.400000              0.100000               0.001000
# 3                   0.400000              0.100000               0.001000
# 4                   0.531962              0.306633               0.063122
# 5                   0.622606              0.281124               0.035013
# ..                       ...                   ...                    ...
# 96                  0.417813              0.254311               0.087307
# 97                  0.655377              0.121679               0.069088
# 98                  0.553626              0.269295               0.088872
# 99                  0.557788              0.244162               0.008912
# 100                 0.275115              0.317211               0.067496
#
#      microp_aero_wsub_scale  microp_aero_wsubi_scale  microp_aero_npccn_scale  \
# 1                  1.000000                 1.000000                 1.000000
# 2                  1.000000                 1.000000                 1.000000
# 3                  0.844572                 1.458654                 1.000000
# 4                  0.723358                 1.783946                 1.071789
# 5                  0.445611                 1.584142                 1.127913
# ..                      ...                      ...                      ...
# 96                 0.797482                 1.005163                 1.338396
# 97                 0.268487                 1.640843                 2.445970
# 98                 0.853614                 1.877448                 2.052206
# 99                 0.738955                 1.690509                 1.069090
# 100                0.304635                 1.878027                 1.209357
#
#      hetfrz_bc_scalfac  hetfrz_dust_scalfac  micro_mg_vtrms_factor
# 1             0.010000             0.050000               1.000000
# 2             0.010000             0.050000               1.000000
# 3             0.010000             0.050000               1.000000
# 4             0.059513             0.258137               2.242130
# 5             0.026793             0.333741               1.783660
# ..                 ...                  ...                    ...
# 96            0.024834             0.237751               2.186996
# 97            0.035084             0.284705               2.254403
# 98            0.033434             0.155131               1.976358
# 99            0.033031             0.087610               1.866280
# 100           0.029916             0.149287               1.338935
#
# [100 rows x 38 columns]

# %%
analysis.visualize_check('PRECT_zonal_-5to5')

# %%
analysis.data.pd_ppe.head(3)['SWCF_zonal_-5to5']
# Out:
# ppe_ind
# 1   -59.740660
# 2   -59.005750
# 3   -59.253113
# Name: SWCF_zonal_-5to5, dtype: float64

# %%
analysis.data.ppe_para.head(3).T
# Out:
#                                       1             2             3
# micro_mg_max_nicons        1.000000e+08  1.000000e+08  1.000000e+08
# micro_mg_vtrmi_factor      1.200000e+00  1.000000e+00  1.366512e+00
# micro_mg_iaccr_factor      1.000000e+00  1.000000e+00  1.000000e+00
# micro_mg_berg_eff_factor   1.000000e+00  1.000000e+00  1.000000e+00
# micro_mg_accre_enhan_fact  1.000000e+00  1.000000e+00  8.164318e-01
# micro_mg_homog_size        2.500000e-05  2.500000e-05  2.500000e-05
# micro_mg_dcs               5.000000e-04  5.000000e-04  5.030000e-04
# clubb_c1                   1.000000e+00  1.000000e+00  1.000000e+00
# clubb_C8                   4.600000e+00  4.500000e+00  4.499788e+00
# clubb_c11                  7.000000e-01  7.000000e-01  7.000000e-01
# clubb_c14                  1.600000e+00  1.600000e+00  1.600000e+00
# clubb_gamma_coef           3.000000e-01  3.000000e-01  3.000000e-01
# clubb_wpxp_L_thresh        6.000000e+01  6.000000e+01  6.000000e+01
# clubb_beta                 2.400000e+00  2.400000e+00  2.400000e+00
# clubb_C2rt                 1.000000e+00  1.000000e+00  1.000000e+00
# clubb_c_uu_shr             1.000000e-01  1.000000e-01  1.000000e-01
# clubb_c_uu_buoy            3.000000e-01  3.000000e-01  3.000000e-01
# zmconv_c0_lnd              3.500000e-03  3.500000e-03  3.916300e-03
# zmconv_c0_ocn              3.000000e-02  3.000000e-02  3.000000e-02
# zmconv_ke                  5.000000e-06  5.000000e-06  5.000000e-06
# zmconv_dmpdz              -1.000000e-03 -1.000000e-03 -1.000000e-03
# cldfrc_dp1                 1.000000e-01  1.000000e-01  9.398960e-02
# cldfrc_dp2                 5.000000e+02  5.000000e+02  5.000000e+02
# zmconv_num_cin             1.000000e+00  1.000000e+00  1.000000e+00
# zmconv_tiedke_add          5.000000e-01  5.000000e-01  5.000000e-01
# zmconv_capelmt             7.000000e+01  7.000000e+01  7.000000e+01
# seasalt_emis_scale         1.250000e+00  1.250000e+00  1.250000e+00
# dust_emis_fact             3.200000e+00  3.200000e+00  4.000000e+00
# sol_factb_interstitial     1.000000e-01  1.000000e-01  1.000000e-01
# sol_factic_interstitial    4.000000e-01  4.000000e-01  4.000000e-01
# microp_aero_wsub_min       1.000000e-01  1.000000e-01  1.000000e-01
# microp_aero_wsubi_min      1.000000e-03  1.000000e-03  1.000000e-03
# microp_aero_wsub_scale     1.000000e+00  1.000000e+00  8.445722e-01
# microp_aero_wsubi_scale    1.000000e+00  1.000000e+00  1.458654e+00
# microp_aero_npccn_scale    1.000000e+00  1.000000e+00  1.000000e+00
# hetfrz_bc_scalfac          1.000000e-02  1.000000e-02  1.000000e-02
# hetfrz_dust_scalfac        5.000000e-02  5.000000e-02  5.000000e-02
# micro_mg_vtrms_factor      1.000000e+00  1.000000e+00  1.000000e+00
